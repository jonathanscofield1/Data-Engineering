# %% [markdown]
# # **Web Scraping  Using Pandas and Selenium**
# > ## - Jonathan Scofield
# >> ###          2/17/2024

# %% [markdown]
# ## **Introduction**
#
# > #### This project demonstrates how to use the Python **selenium** library to extract table data from a dynamically loaded web page. Popular web scraping libraries such as **Beautiful Soup** and **requests** work well with static web pages; however, they cannot easily parse dynamically loaded web pages. **Selenium WebDriver** interacts with web pages as a browser, enabling it to interact with the web pages **JavaScript** and trigger events.
#
# > #### This project uses public well data from the [Geological Survey of Alabama](https://www.gsa.state.al.us/). The parent web page for this project can be found at https://www.gsa.state.al.us/ogb/wells. We will use the hyperlinks in the API column to obtain additional information about the wells. A sample of what a child page might look like can be found here: https://www.gsa.state.al.us/ogb/wells/details/construct/17323-B-1/26114/32904/404/221100
#
# > #### **IMPORTANT:** *The web pages used in this project are not owned by the author and may be removed or altered at any time. The author has provided copies of these pages for reference in this repository.*

# %% [markdown]
# ## **Setup and Requirements**
#
# > #### The following dependencies must be installed:
# >> \#!pip install pandas==2.0.3 selenium==4.17.2 chromedriver-autoinstaller==0.6.4

# %%
# Import libraries
import chromedriver_autoinstaller
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd

# %%
# Required to use the Chrome driver in selenium
#chromedriver_autoinstaller.install()

# %% [markdown]
# ## **Classes and Methods**

# %% [markdown]
# ### **Parent Class**
#
# > #### This class will serve as our basic class for scraping a webpage. It starts the selenium WebDriver when called and contains 3 methods:
# >> 1. **extract_text()** will extract the anchor text from the HTML href tag in all columns except where indicated. Pandas returns href tags as a tuple: (anchor text, hyperlink).
# >> 2. **get_html_table()** will load a web page from a given url, waiting until JavaScript loads tables. It then uses the Pandas **read_html()** method to extract the table and load into a Pandas DataFrame.
# >> 3. **close_browser()** will close the browser once all crawling operations have completed.

# %%
class WebPage:
    
    def __init__(self):
        self.driver = webdriver.Chrome() # Start web driver
        
    # When extracting links in Pandas, the href and link text are returned as tuples.
    # The following function will return only the link text for all columns excluded from link_fields
    def extract_text(self, df, href_columns): 
        for column in df.columns.to_list():
            df[column] = df[column].map(lambda x: x[0] if column not in href_columns else x)
        return df
    
    # This function extracts HTML from the webpage using Pandas
    def get_html_table(self, url, href_columns = [], table_index = 0):
        preserve_links = len(href_columns) > 0 
        self.driver.get(url) # Load the web page
        WebDriverWait(self.driver, 10).until(
        EC.presence_of_element_located(
            (By.TAG_NAME, "table"))) # Important: wait for tables to load before returning HTML
        html = self.driver.page_source # Return HTML
        # Use Pandas to extract tables via HTML tags
        tables = pd.read_html(html, extract_links = 'body', flavor = 'bs4') if preserve_links else pd.read_html(html, flavor = 'bs4')
        df = pd.DataFrame(tables[table_index])
        # Return the data frame with selected links preserved a tuples
        return self.extract_text(df, href_columns) if preserve_links != 0 else df
    
    def close_browser(self): # This function closes the browser
        self.driver.quit()

# %% [markdown]
# ### **Child Class**
#
# > #### This class extends the parent class by allowing us to follow embedded links in our table. When calling the class, we pass all the parameters needed to locate the table of parent page. It contains 3 methods:
# >> 1. **get_links()** creates a dictionary object from the columns which preserve links. This is needed to crawl the child tables.
# >> 2. **format_child_url()** takes the partial url returned in the tuple and combines it with the parent url by removing overlapping directories using Python set operations.
# >> 3. **get_linked_table()** follows a link and return another table ONLY if the anchor text is present in the parent table.

# %%
class ChildPage(WebPage): #Child class of web page
    
    def __init__(self, parent_url, href_columns, parent_table_index):
        super().__init__() # This class inherits all attributes from parent class
        self.parent_url = parent_url
        self.href_columns = href_columns # Preserve links in these columns
        self.parent_table_index = parent_table_index # In case of multiple tables
        self.parent_df = self.get_html_table(url = self.parent_url, href_columns = self.href_columns, table_index = self.parent_table_index) 
        
    # Create a dictionary from columns containing link tuples as {column: {anchor: link}}
    # Uses format_child_url (below) to fix url formatting
    def get_links(self): 
        return {href_column : {anchor_text: self.format_child_url(link) for anchor_text, link in self.parent_df[href_column].to_list()} for href_column in self.href_columns}

    # Function to join partial child url with parent url
    def format_child_url(self, child_url): 
        child_url = str(child_url) # Partial url for child page
        parent_url_dir = set(self.parent_url.split('/')) # Extract directories from parent url
        child_url_dir = set(child_url.split('/')) # Extract directories from child url
        common_dir = parent_url_dir & child_url_dir # Intersection of directories
        for element in common_dir: # Delete elements in place and remove doubled slashes
            child_url = child_url.replace(element, '').replace('//', '/') 
        return self.parent_url + child_url # Combine and remove overlap
    
    def get_linked_table(self, href_column, anchor_text):
        link_dict = self.get_links() # Load link dictionary
        link = link_dict[href_column].get(anchor_text, None) # Get link value
        df = self.get_html_table(url = link) # Follow link using inherited method
        df[href_column] = anchor_text # Adds a new column with the anchor text for clarity
        return df

# %% [markdown]
# ### **Demonstration**

# %% [markdown]
# #### Retrieve the oil well table from the main page and preserve links in the "API" and "Online Map" columns

# %%
oil_wells = ChildPage('https://www.gsa.state.al.us/ogb/wells', ['API', 'Online Map'], 0)

# %%
oil_wells.parent_df
# Out:
#               Permit                                                API  \
# 0           17469-CG  (01073219420000, /ogb/wells/details/construct/...
# 1              17468  (01013200050000, /ogb/wells/details/construct/...
# 2              17467  (01013200040000, /ogb/wells/details/construct/...
# 3           17466-CG  (01073219410000, /ogb/wells/details/construct/...
# 4           17465-CG  (01125263000000, /ogb/wells/details/construct/...
# 5              17464  (01013200030000, /ogb/wells/details/construct/...
# 6           17463-CG  (01073219400000, /ogb/wells/details/construct/...
# 7            17462-B  (01035203790000, /ogb/wells/details/construct/...
# 8           17461-CG  (01125262990000, /ogb/wells/details/construct/...
# 9           17460-CG  (01073219390000, /ogb/wells/details/construct/...
# 10   2011-B-WI-23-02  (01025200680002, /ogb/wells/details/construct/...
# 11             17459  (01099203380000, /ogb/wells/details/construct/...
# 12           13195-A  (01107202900001, /ogb/wells/details/construct/...
# 13             10200  (01099201430001, /ogb/wells/details/construct/...
# 14              4369  (01107200510001, /ogb/wells/details/construct/...
# 15          17458-CG  (01073219380000, /ogb/wells/details/construct/...
# 16          17457-CG  (01073219370000, /ogb/wells/details/construct/...
# 17          17456-CG  (01073219360000, /ogb/wells/details/construct/...
# 18          17455-CG  (01125262980000, /ogb/wells/details/construct/...
# 19          17454-CG  (01125262970000, /ogb/wells/details/construct/...
# 20          17453-CG  (01073219350000, /ogb/wells/details/construct/...
# 21          17452-CG  (01125262960000, /ogb/wells/details/construct/...
# 22          17451-CG  (01125262950000, /ogb/wells/details/construct/...
# 23           17450-C  (01073219340000, /ogb/wells/details/construct/...
# 27          Wildcat                                  Lamar      34  17S 15W
# 28         Brooklyn  Tuscaloosa (water source)     Conecuh       3   3N 13E
# 29        Oak Grove   Pottsville Coal Interval  Tuscaloosa      13   19S 8W
# 30        Oak Grove   Pottsville Coal Interval  Tuscaloosa      11   19S 8W
# 31        Oak Grove   Pottsville Coal Interval   Jefferson       7   19S 6W
# 32        Oak Grove   Pottsville Coal Interval   Jefferson       7   19S 6W
# 33  White Oak Creek   Pottsville Coal Interval  Tuscaloosa       4   17S 8W
# 34  White Oak Creek   Pottsville Coal Interval  Tuscaloosa       4   17S 8W
# 35  White Oak Creek   Pottsville Coal Interval  Tuscaloosa       5   17S 8W
# 36  White Oak Creek   Pottsville Coal Interval  Tuscaloosa       4   17S 8W
# 37  White Oak Creek   Pottsville Coal Interval  Tuscaloosa       5   17S 8W
# 38        Oak Grove   Pottsville Coal Interval   Jefferson      34   18S 7W
# 39        Oak Grove   Pottsville Coal Interval   Jefferson      34   18S 7W
# 40          Wildcat                                Pickens       3  22S 16W
# 41         Star Gas                        Box       Lamar       1  16S 16W
# 42          Wildcat                                Pickens       8  19S 13W
# 43         Star Gas                      Lewis       Lamar      20  16S 15W
# 44         Star Gas               Pottsville A       Lamar      18  16S 15W
# 45        Oak Grove   Pottsville Coal Interval   Jefferson      13   19S 7W
# 46        Oak Grove   Pottsville Coal Interval   Jefferson      13   19S 7W
# 47        Oak Grove   Pottsville Coal Interval  Tuscaloosa      11   19S 8W
# 48         Brooklyn                  Smackover     Conecuh      10   3N 13E
# 49        Oak Grove   Pottsville Coal Interval   Jefferson      26   18S 5W
#
#    Unit Acres                                Unit Description         Lon  \
# 0                                                        VI-C    -87.2571
# 1         160                                              SE   -86.79062
# 2         160                                              SE   -86.70578
# 3                                                   Unit VI-B   -87.21371
# 4                                     Unit 1 (gob wells only)   -87.39608
# 5         160                                              NE    -86.7948
# 6                         VI-C (gob and horizontal boreholes)   -87.24975
# 7         160                                              SE   -87.28168
# 8                                     Unit 1 (GOB wells only)   -87.39097
# 9          80                                           W2 NW   -87.24553
# 10             South Carlton Field-Wide Lower Tuscaloosa Unit   -87.87704
# 11        160                    S2 SW Sec. 29, N2 NW Sec. 32   -87.59588
# 12        320                                              E2   -88.12603
# 13         40                                           SW SW   -87.41017
# 14        320                                              E2  -87.916264
# 15                        VI-B (gob and horizontal boreholes)   -87.22423
# 16                        VI-B (gob and horizontal boreholes)   -87.21818
# 17                        VI-C (gob and horizontal boreholes)   -87.24949
# 18                        VI-C (gob and horizontal boreholes)   -87.23826
# 19                        VI-C (gob and horizontal boreholes)    -87.2336
# 20                        VI-B (gob and horizontal boreholes)    -87.2287
# 21                                    Unit 1 (gob wells only)   -87.39082
# 22                                    Unit 1 (gob wells only)   -87.39637
# 23         80                                           W2 NE   -87.01229
# 24         80                                           W2 SW   -87.02115
# 25                                       Brooklyn Oil Unit II   -86.72847
# 26        160                                              SE   -87.28168
# 27         40                                           NE SW   -88.09638
# 28                                       Brooklyn Oil Unit II   -86.73665
# 29         80                                           N2 NW   -87.33334
# 30         40                                           SE SE   -87.33712
# 31                        VI-B (gob and horizontal boreholes)   -87.21267
': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17452-CG/27384/32931/227/327100',
#   '01125262950000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17451-CG/27383/32930/227/327100',
#   '01073219340000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17450-C/27382/32929/84/327100',
#   '01073219330000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17449-C/27381/32928/84/327100',
#   '01035203550001': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17273-B-WI-23-01/26064/32927/404/221100',
#   '01035203780000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17448-B/27380/32926/289/221100',
#   '01075205500002': 'https://www.gsa.state.al.us/ogb/wells/details/construct/4055-A/6444/32925/0/',
#   '01035203460001': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17207-WS-B/5965/32924/404/211500',
#   '01125262940000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17447-CG/27379/32923/84/327100',
#   '01125262930000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17446-CG/27378/32922/84/327100',
#   '01073219320000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17445-CG/27377/32921/84/327100',
#   '01073219310000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17444-CG/27376/32920/84/327100',
#   '01125262920000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17443-C/27375/32919/247/327100',
#   '01125262910000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17442-C/27374/32918/247/327100',
#   '01125262900000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17441-C/27373/32917/247/327100',
#   '01125262890000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17440-C/27372/32916/247/327100',
#   '01125262880000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17439-C/27371/32915/247/327100',
#   '01073219300000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17438-CG/27370/32914/84/327100',
#   '01073219290000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17437-CG/27369/32913/84/327100',
#   '01107203120003': 'https://www.gsa.state.al.us/ogb/wells/details/construct/14371-A/5441/32912/0/',
#   '01075208570001': 'https://www.gsa.state.al.us/ogb/wells/details/construct/9085-A/16605/32911/41/327300',
#   '01107204320000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17436/27368/32910/0/',
#   '01075207590003': 'https://www.gsa.state.al.us/ogb/wells/details/construct/5450-A/13012/32909/41/331700',
#   '01075204040002': 'https://www.gsa.state.al.us/ogb/wells/details/construct/3433/16519/32908/41/327A00',
#   '01073219280000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17435-CG/27367/32907/84/327100',
#   '01073219270000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17434-CG/27366/32906/84/327100',
#   '01125262870000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17433-CG/27365/32905/84/327100',
#   '01035203650100': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17323-B-1/26114/32904/404/221100',
#   '01073219260000': 'https://www.gsa.state.al.us/ogb/wells/details/construct/17432-C/27364/32903/84/327100'},
#  'Online Map': {'': 'https://www.gsa.state.al.us/ogb/wells/apps/maps/?query=map_1748_3%2CWEBOGBSDE.DBO.WebWell_Prj.Permit%2C17432-C'}}

# %% [markdown]
# #### Get casing data for well with API 01035203650100 (index 48). *Note: the casing table is the first table that appears via the child link, so the default index will suffice*

# %%
oil_wells.get_linked_table('API','01035203650100')
# Out:
#   Feature  Diameter  Inside Diameter  Casing Top  Casing Bottom  Pressure  \
# 0    COND    20.000              NaN         0.0           80.0       NaN
# 1    HOLE    12.250              NaN         0.0         2679.0       NaN
# 2    SURF     9.625              NaN         0.0         2679.0       NaN
# 3    HOLE     8.750              NaN      2679.0        12274.0       NaN
# 4     NaN       NaN              NaN         NaN            NaN       NaN
# 5     NaN       NaN              NaN         NaN            NaN       NaN
#
#    Recovered  Comment             API
# 0        NaN      NaN  01035203650100
# 1        NaN      NaN  01035203650100
# 2        NaN      NaN  01035203650100
# 3        NaN      NaN  01035203650100
# 4        NaN      NaN  01035203650100
# 5        NaN      NaN  01035203650100

# %%
oil_wells.close_browser()

# %% [markdown]
# ### **References**
#
# > - https://medium.com/thedevproject/how-to-scrape-javascript-heavy-sites-like-a-pro-with-python-1ecf6f829538
# > - https://selenium-python.readthedocs.io/
# > - https://pandas.pydata.org/pandas-docs/version/2.0.3/
